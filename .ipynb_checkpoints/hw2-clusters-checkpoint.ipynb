# %% [markdown]
# # Алгоритмы интеллектуальной обработки больших объемов данных
# ## Домашнее задание №2 - Алгоритмы кластеризации

# %% [markdown]
# ###### <hr\>
# **Общая информация**
#
# **Срок сдачи:** 13 марта 2017, 06:00 <br\>
# **Штраф за опоздание:** -2 балла после 06:00 13 марта, -4 балла после 06:00 20 марта, -6 баллов после 06:00 27 марта
#
# Отправлять дз не нужно, нужно закоммитить в github. Сдается дз лично преподавателю на рубежном контроле (13 марта)
#
# Используйте данный Ipython Notebook при оформлении домашнего задания.
# <hr\>

# %% [markdown]
# Основная задача этого задания - реализация одного из алгоритмов кластеризации. Кроме того, мы научимся подбирать параметры алгоритма, визуализируем результат кластеризации и попытаемся проанализировать природу полученных кластеров.

# %%
import pandas as pd
import pylab as pl
import numpy as np
from numba import jitclass          # import the decorator
import scipy.spatial as ss
import sklearn.cluster as sc
import sklearn.manifold as sm
import sklearn.datasets as ds
import sklearn.metrics as smt
from collections import Counter

import matplotlib.pyplot as plt
import mpl_toolkits.basemap as bm

# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12,5)

# Plotting config
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Реализация алгоритма

# %% [markdown]
# Cчитываем данные, полученные в результате выполнения домашнего задания из курса введения, в `data frame` библиотеки `pandas`. Достаем координаты и конвертируем в массив `numpy`. Возможно, в собранном вами файле кодировка будет иной.

# %%
data_df = pd.read_csv("data_vk.csv", encoding='utf-8', index_col="Unnamed: 0")
data_df.head()
# Out:
#                 address  checkins  city  country              created  \
# 1     Мячковский б-р 3а       435     1        1  2010-08-02 12:39:01
# 2             Дачная 2а        14   123        1  2010-08-02 12:39:01
# 3      Лени Голикова 29         8     2        1  2010-08-02 12:39:01
# 4  Героев Танкограда 63         8   158        1  2010-08-02 12:39:01
# 5     Мусы Джалиля 14К1        38    99        1  2010-08-02 12:39:01
#
#                                      icon   latitude  longitude        title  \
# 1  https://vk.com/images/places/clubs.png  55.657941  37.751574  Baila Baila
# 2  https://vk.com/images/places/clubs.png  53.202017  50.141377         Lust
# 3  https://vk.com/images/places/clubs.png  59.843376  30.231480       Тайфун
# 4  https://vk.com/images/places/clubs.png  55.174954  61.451611    Hollywood
# 5  https://vk.com/images/places/clubs.png  54.860834  83.091932      Барабас
#
#    type       updated
# 1     4  1.487519e+09
# 2     4  1.483478e+09
# ...

# %%
x = data_df[['latitude', 'longitude']].values
print x
# Out:
# [[ 55.657941  37.751574]
#  [ 53.202017  50.141377]
#  [ 59.843376  30.23148 ]
#  ...,
#  [ 55.76363   37.597046]
#  [ 56.002732  37.209755]
#  [ 47.225695  39.72997 ]]

# %% [markdown]
# Алгоритм кластеризации, который необходимо реализовать, выбирается на основании Вашего порядкового номера в списке группы.

# %% [markdown]
# 1 Баранчиков Максим
# 2 Бекбулатов Рамзан
# 3 Белозёров Михаил
# 4 Бобылев Владислав
# 5 Брызгалов Антон
# 6 Будюк Алексей
# 7 Валиуллин Альберт
# 8 Валиуллин Артур
# 9 Васильев Евгений
# 10 Галицкий Игорь
# 11 Горшков Сергей
# 12 Гусев Вячеслав
# 13 Дегтярев Роман
# 14 Дементьев Максим
# 15 Елохов Артур
# 16 Ефимов Владислав
# 17 Зайцев Александр
# 18 Ильин Иван
# 19 Имеев Мерген
# 20 Камалбеков Тимур
# 21 Капитонов Александр
# 22 Каспарьянц Георгий
# 23 Кафанов Олег
# 24 Клейменов Андрей
# 25 Козлов Иван
# 26 Колмакова Татьяна
# 27 Комов Евгений
# 28 Крылов Иван
# 29 Кузьмина Ирина
# 30 Куклева Анна
# 31 Курьянов Илья
# 32 Лобанов Алексей
# 33 Лозинский Иван
# 34 Лузин Игорь
# 35 Лукьянчиков Иван
# 36 Неред Максим
# 37 Новикова Анастасия
# 38 Новичков Сергей
# 39 Омаров Темирхан
# 40 Павлова Анастасия
# 41 Петренко Иван
# 42 Пилюгин Вадим
# 43 Плошкин Александр
# 44 Полякова Вера
# 45 Попкова Екатерина
# 46 Преображенский Анатолий
# 47 Пронин Сергей
# 48 Пучкин Данила
# 49 Рогачев Александр
# 50 Руденко Дмитрий
# 51 Рыбаков Владислав
# 52 Санников Артём
# 53 Скиба Глеб
# 54 Страдомский Сергей
# 55 Тескер Константин
# 56 Трифанов Петр
# 57 Хапкин Артем
# 58 Хорошенький Илья
# 59 Чокля Дмитрий
# 60 Шмурак Денис
# 61 Щербакова Елена

# %%
N = 33 # put your index here

# %%
algorithms = [
    u"Gaussian Mixture Model с использованием maximum a-posteriori для выбора кластера (параметр - k)",
    u"Hierarchical clustering с поддержкой single-linkage, complete-linkage, average-linkage (параметры - k, linkage)",
    u"DBSCAN. (параметры - epsilon, min_pts)", 
    u"OPTICS. (параметры - epsilon, min_pts)"
]

my_algorithm = algorithms[N % len(algorithms)]
print u"Реализуем алгоритм кластеризации '%s'" % my_algorithm
# Out:
# Реализуем алгоритм кластеризации 'Hierarchical clustering с поддержкой single-linkage, complete-linkage, average-linkage (параметры - k, linkage)'

# %% [markdown]
# **По разрешения преподавателя Ксении Стройковой реализую "Gaussian Mixture Model с использованием maximum a-posteriori для выбора кластера (параметр - k)"**

# %% [markdown]
# Алгоритм кластеризации должен удовлетворять следующему интерфейсу. Конструктор принимает набор параметров, необходимых для работы алгоритма кластеризации. Метод `fit` подсчитывает параметры модели и возвращает `self`. Метод `predict` возвращает вектор с индексами кластеров для поданных в него объектов `x`

# %%
from sklearn.base import BaseEstimator, ClusterMixin

class EMClustering(BaseEstimator, ClusterMixin):
    """
    Implement clustering algorithm according 
    """
    
    def __init__(self, k, eps = 0.01, maxstep = 2000):
        self.k = k
        self.eps = eps
        self.maxstep = maxstep
        return
    
    def fit(self, x, y=None):
        # C - average values matrix (size*k)
        # R - kovariation matrix (size*size)
        # W - weight matrix (k*1)
        size = x.shape[1]
        n = x.shape[0]
        self.size = size
        
        # init matrix
        C = np.empty((size, self.k))
        for i in xrange(size):
            C[i,:] = np.random.choice(x[:, i], (1, self.k))
        R = np.identity(size)
        W = np.full((self.k,1), 1./self.k)
        self.probabilityMatrix = np.empty((n, self.k))
        
        dllh = self.eps+1;
        llh = 0
        step = 0
        
        while (dllh >= self.eps and step <= self.maxstep):
            # E step
            llh_old = llh
            llh = 0
            C1 = np.zeros(C.shape)
            R1 = np.zeros(R.shape)
            W1 = np.zeros(W.shape)
            P = np.empty((n, self.k))
            Rinv = np.linalg.inv(R)
            detR = np.linalg.det(R)
            for i in xrange(n):
                sumpi = 0
                for j in xrange(self.k):
                    # Mahalanobisis distant
                    dist = (x[i] - C[:, j]).reshape(1, -1).dot(Rinv).dot((x[i] - C[:, j]).reshape(-1, 1))[0,0]
                    
                    P[i,j] = W[j]/((2*math.pi) ** (size/2.)  * detR ** 0.5) * math.exp(-0.5 * dist)
                    sumpi = sumpi + P[i,j]
                
                sumpi = sumpi if sumpi > 0 else 1
                self.probabilityMatrix[i] = P[i]/sumpi
                llh = llh + math.log(sumpi)
                C1 = C1 + x[i].reshape(-1, 1).dot(self.probabilityMatrix[i].reshape(1,-1))
                W1 = W1 + self.probabilityMatrix[i].reshape(-1, 1)
            
            # M step
            
            for j in xrange(self.k):
                C[:, j] = C1[:, j] / W1[j]
                for i in xrange(n):
                    R1 = R1 + ((x[i] - C[:, j]).reshape(-1, 1)*self.probabilityMatrix[i, j]).dot((x[i] - C[:, j]).reshape(1, -1))
            R = R1 / n
            W = W1 / n
            
            step += 1
            dllh = math.fabs(llh_old - llh)
        self.R = R
        self.W = W
        self.C = C
        self.x_len = len(x)
        return self
    
    def predict(self, x):
        n = x.shape[0]
        P = np.empty((n, self.k))
        Rinv = np.linalg.inv(self.R)
        detR = np.linalg.det(self.R)
        for i in xrange(n):
            sumpi = 0
            for j in xrange(self.k):
                # Mahalanobisis distant
                dist = (x[i] - self.C[:, j]).reshape(1, -1).dot(Rinv).dot((x[i] - self.C[:, j]).reshape(-1, 1))[0,0]
                P[i,j] = self.W[j]/((2*math.pi) ** (self.size/2.)  * detR ** 0.5) * math.exp(-0.5 * dist)
                sumpi = sumpi + P[i,j]
            
            P[i] = P[i]/sumpi
        
        return np.argmax(P, axis=1)
    
    def fit_predict(self, x, y=None):
        self.fit(x, y)
        return self.predict(x)

# %% [markdown]
# Сначала проверим реализованный алгоритм кластеризации на классическом наборе данных [Iris](http://www.wikiwand.com/en/Iris_flower_data_set). Загрузим данные (они включены в библиотеку sklearn) и посмотрим на то, как они выглядят в двух проекциях (для простоты используем 2 класса из 3).

# %%
iris = ds.load_iris()
x_iris = iris.data[:100]
y_iris = iris.target[:100]

pl.figure(figsize=(10, 5))

pl.subplot(1, 2, 1)
pl.scatter(x_iris[:, 0], x_iris[:, 1], c=y_iris, cmap=pl.cm.PuOr, lw=0, s=30)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')

pl.subplot(1, 2, 2)
pl.scatter(x_iris[:, 2], x_iris[:, 3], c=y_iris, cmap=pl.cm.PuOr, lw=0, s=30)
plt.xlabel('Petal length')
plt.ylabel('Petal width')
pl.show()

# %% [markdown]
# Видно, что классы разделяются, поэтому можно надеяться, что наш алгоритм "найдет" кластеры, соответствующие исходным классам. Результат работы реализованного алгоритма кластеризации предлагается сравнить с эталонной кластеризацией. Для этого предлагается изучить метрику ([adjusted rand score](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.adjusted_rand_score.html)). В случае если значение этой метрики отличается от 1, предлагается поработать над улучшением реализации своего алгоритма.

# %%
pred_iris = EMClustering(2).fit_predict(x_iris)
print "Adjusted Rand index for iris is: %.2f" % smt.adjusted_rand_score(y_iris, pred_iris)
# Out:
# Adjusted Rand index for iris is: 1.00

# %% [markdown]
# Выбрать и реализовать критерий качества, на основании которого будут подбираться параметры модели. Варианты критериев:
# - Инерция (сумма квадратов расстояний от каждой из точек до ближайшего к этой точке центроида)
# - Средний диаметр (максимальное расстояние между точками в кластере) или радиус (расстояние от центроида до самой дальней от него точки в кластере)
# - Sihouette
#
# **Критерий качества необходимо выбрать таким образом, чтобы он подходил для реализованного алгоритма**

# %%
def quality(x, y):
    c = Counter(y)
    a = 0
    for key in c:
        arr = x[y==key]
        m = 0
        for i in xrange(c[key]):
            for j in xrange(c[key]):
                m = max(m, (x[i,0]-x[j,0])**2 + (x[i,1]-x[j,1])**2)
        a += m
    return float(a)/len(c)

# %% [markdown]
# Применим критерий для выбора параметров алгоритма. Предлагается изменить следующий код таким образом, чтобы кластеризация вызывалась с верным набором параметров. На графике можно будет увидеть зависимость критерия от параметров алгоритма. Необходимо выбрать оптимальные значения этих параметров.

# %%
ks = range(5,10)
criteria = np.zeros(len(ks))

for i, k in enumerate(ks):
    cls = EMClustering(k)
    y = cls.fit_predict(x)
    criteria[i] = quality(x, y)
    
pl.figure(figsize=(8, 6))
pl.plot(ks, criteria)
pl.title("$J(k)$")
pl.ylabel("Criteria $J$")
pl.xlabel("Number of clusters $k$")
pl.grid()
pl.show()

# %% [markdown]
# Далее необходимо кластеризовать данные, используя выбранное количество кластеров, и визуализировать результат. Внимание! На полном объеме данных данный алгоритм может работать существенное время.

# %%
k = 7
cls = EMClustering(k)
y = cls.fit_predict(x)

# %% [markdown]
# Визуализируем кластеризацию на карте

# %%
pl.figure(figsize=(20,12))

m = bm.Basemap(projection='cyl', llcrnrlat=min(x[:, 0]) - 5, urcrnrlat=max(x[:, 0]) + 5, llcrnrlon=min(x[:, 1]) - 5, urcrnrlon=max(x[:, 1]) + 5, resolution='c')

m.drawcountries(linewidth=0.2)
m.fillcontinents(color='lavender', lake_color='#000040')
m.drawmapboundary(linewidth=0.2, fill_color='#000040')
m.drawparallels(np.arange(-90,90,30),labels=[0,0,0,0], color='white', linewidth=0.5)
m.drawmeridians(np.arange(0,360,30),labels=[0,0,0,0], color='white', linewidth=0.5)

m.scatter(x[:, 1], x[:,0], c=y, zorder=10)
    
pl.show()
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\mpl_toolkits\basemap\__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()
# C:\ProgramData\Anaconda2\lib\site-packages\mpl_toolkits\basemap\__init__.py:3222: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# C:\ProgramData\Anaconda2\lib\site-packages\mpl_toolkits\basemap\__init__.py:3231: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %% [markdown]
# Визуализируйте интересные участки (может быть это Москва) в приближенном виде. Постройте 3 (или более, в зависимости от данных, что вам самим бы хотелось увидеть ближе) увеличенных изображений карты с кластеризацией.

# %%
import folium
from folium.plugins import MarkerCluster

mos_center = [55.750475, 37.619020]
mos_min_lat, mos_max_lat = 55.564141, 55.908930
mos_min_lon, mos_max_lon = 37.344362, 37.879945
pit_center = [59.89444, 30.26417]
pit_min_lat, pit_max_lat = 59.741243, 60.101130
pit_min_lon, pit_max_lon = 29.998115, 30.555671

sad_ring_rad = (mos_center[0] - 55.760188)**2 + (mos_center[1] - 37.658155)**2

# %%
data_moscow_p = data_df[data_df.latitude.between(mos_min_lat, mos_max_lat) &
                   data_df.longitude.between(mos_min_lon, mos_max_lon)]
data_moscow_pp = data_moscow_p[['latitude', 'longitude']].values

k = 8
cls = EMClustering(k)
y = cls.fit_predict(data_moscow_pp)


moscow = folium.Map(location=mos_center, zoom_start=11, control_scale=True) 

for c in xrange(k):
    data_moscow = data_moscow_pp[y == c]
    for i,j in data_moscow:
        folium.RegularPolygonMarker(
        [i, j],
        fill_color='#132b5e',
        number_of_sides=3+c,
        radius=6
        ).add_to(moscow)
moscow
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
data_moscow_center = data_df[(data_df.latitude - mos_center[0])**2 + (data_df.longitude - mos_center[1])**2 <= sad_ring_rad]
data_moscow_pp = data_moscow_center[['latitude', 'longitude']].values
k = 5
cls = EMClustering(k)
y = cls.fit_predict(data_moscow_pp)

moscow = folium.Map(location=mos_center, zoom_start=13, control_scale=True) 

for c in xrange(k):
    data_moscow = data_moscow_pp[y == c]
    for i,j in data_moscow:
        folium.RegularPolygonMarker(
        [i, j],
        fill_color='#132b5e',
        number_of_sides=3+c,
        radius=6
        ).add_to(moscow)
moscow
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
# Питер

data_piter_p = data_df[data_df.latitude.between(pit_min_lat, pit_max_lat) &
                   data_df.longitude.between(pit_min_lon, pit_max_lon)]
data_piter_pp = data_piter_p[['latitude', 'longitude']].values
print data_piter_pp.shape
k = 8
cls = EMClustering(k)
y = cls.fit_predict(data_piter_pp)


piter = folium.Map(location=pit_center, zoom_start=11, control_scale=True) 

for c in xrange(k):
    data_piter = data_piter_pp[y == c]
    for i,j in data_piter:
        folium.RegularPolygonMarker(
        [i, j],
        fill_color='#132b5e',
        number_of_sides=3+c,
        radius=6
        ).add_to(piter)
piter
# Out:
# (1210L, 2L)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# Какой вывод можно сделать о качестве кластеризации?

# %% [markdown]
# Поздравляем, Вы завершили домашние задания по модулю "Алгоритмы кластеризации". Надеемся, что это было интересно.
